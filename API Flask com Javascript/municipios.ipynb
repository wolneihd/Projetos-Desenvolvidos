# %%
import pandas as pd

# %%
# importar arquivo
tabela = pd.read_csv('./municipios.csv')

# %%
tabela.head()
# Out:
#    municipio  uf uf_code                   name  mesoregion  microregion  \
# 0    1100015  11      RO  Alta Floresta d'Oeste        1102        11006
# 1    1100023  11      RO              Ariquemes        1102        11003
# 2    1100031  11      RO                 Cabixi        1102        11008
# 3    1100049  11      RO                 Cacoal        1102        11006
# 4    1100056  11      RO             Cerejeiras        1102        11008
#
#    rgint     rgi  osm_relation_id wikidata_id is_capital  \
# 0   1102  110005           325842    Q1761456        NaN
# 1   1101  110002           325888    Q1646975        NaN
# 2   1102  110006           325882     Q940433        NaN
# 3   1102  110005           325872    Q1761637        NaN
# 4   1102  110006           325883    Q1803210        NaN
#
#             wikipedia_pt        lon        lat             no_accents  \
# 0  Alta Floresta d'Oeste -61.999824 -11.935540  Alta Floresta d'Oeste
# 1              Ariquemes -63.033269  -9.908463              Ariquemes
# 2                 Cabixi -60.544314 -13.499763                 Cabixi
# 3                 Cacoal -61.442944 -11.433865                 Cacoal
# 4             Cerejeiras -60.818426 -13.195033             Cerejeiras
#
#               slug_name alternative_names  pop_21
# 0  alta-floresta-doeste               NaN   22516
# 1             ariquemes               NaN  111148
# 2                cabixi               NaN    5067
# 3                cacoal               NaN   86416
# 4            cerejeiras               NaN   16088

# %%
# todas as capitais em ordem alfabética
selecao_capital = tabela.query('is_capital == True')
todas_capitais_ordem_alfabetica = selecao_capital.sort_values(by='uf_code').reset_index(drop=True)
todas_capitais_ordem_alfabetica['id'] = todas_capitais_ordem_alfabetica.index
todas_capitais_ordem_alfabetica
# Out:
#     municipio  uf uf_code            name  mesoregion  microregion  rgint  \
# 0     1200401  12      AC      Rio Branco        1202        12004   1201
# 1     2704302  27      AL          Maceió        2703        27011   2701
# 2     1302603  13      AM          Manaus        1303        13007   1301
# 3     1600303  16      AP          Macapá        1602        16003   1601
# 4     2927408  29      BA        Salvador        2905        29021   2901
# 5     2304400  23      CE       Fortaleza        2303        23016   2301
# 6     5300108  53      DF        Brasília        5301        53001   5301
# 7     3205309  32      ES         Vitória        3203        32009   3201
# 8     5208707  52      GO         Goiânia        5203        52010   5201
# 9     2111300  21      MA        São Luís        2101        21002   2101
# 10    3106200  31      MG  Belo Horizonte        3107        31030   3101
# 11    5002704  50      MS    Campo Grande        5002        50004   5001
# 12    5103403  51      MT          Cuiabá        5104        51017   5101
# 13    1501402  15      PA           Belém        1503        15007   1501
# 14    2507507  25      PB     João Pessoa        2504        25022   2501
# 15    2611606  26      PE          Recife        2605        26017   2601
# 16    2211001  22      PI        Teresina        2202        22003   2201
# 17    4106902  41      PR        Curitiba        4110        41037   4101
# 18    3304557  33      RJ  Rio de Janeiro        3306        33018   3301
# 19    2408102  24      RN           Natal        2404        24018   2401
# 20    1100205  11      RO     Porto Velho        1101        11001   1101
# 21    1400100  14      RR       Boa Vista        1401        14001   1401
# 22    4314902  43      RS    Porto Alegre        4305        43026   4301
# 23    4205407  42      SC   Florianópolis        4205        42016   4201
# 24    2800308  28      SE         Aracaju        2803        28011   2801
# 25    3550308  35      SP       São Paulo        3515        35061   3501
# 26    1721000  17      TO          Palmas        1702        17006   1701
#
#        rgi  osm_relation_id wikidata_id is_capital  \
# 0   120001           326253     Q171612       True
# 1   270001           303815     Q168888       True
# 2   130001           332493      Q40236       True
# 3   160001           331473     Q180215       True
# 4   290001           362362      Q36947       True
# 5   230001           302588      Q43463       True
# 6   530001          2758138       Q2844       True
# 7   320001          1825817     Q168376       True
# 8   520001           334547      Q83189       True
# 9   210001           332923      Q28441       True
# 10  310001           368782      Q42800       True
# 11  500001           334022     Q168929       True
# 12  510001           333734     Q170762       True
# 13  150001           185567   Q12829733       True
# 14  250001           301405     Q167436       True
# 15  260001           303585      Q48344       True
# 16  220001           302749     Q165341       True
# 17  410001           297514       Q4361       True
# 18  330001          2697338       Q8678       True
# 19  240001           301091     Q131620       True
# 20  110001           325855     Q172512       True
# 21  140001           326286     Q181056       True
# 22  430001           242397      Q40269       True
# 23  420001           296561     Q132997       True
# 24  280001           303928     Q170578       True
# 25  350001           298285        Q174       True
# 26  170001           336798     Q178993       True
#
#                             wikipedia_pt        lon        lat  \
# 0                             Rio Branco -67.810529  -9.978299
# 1                                 Maceió -35.701630  -9.660822
# 2                                 Manaus -60.023335  -3.134691
# 3                                 Macapá -51.057405   0.038951
# 4                       Salvador (Bahia) -38.488061 -13.014772
# 5                              Fortaleza -38.589928  -3.723805
# 6   Plano Piloto (região administrativa) -47.887905 -15.794087
# 7               Vitória (Espírito Santo) -40.322209 -20.320154
# 8                                Goiânia -49.255814 -16.673310
# 9                    São Luís (Maranhão) -44.297919  -2.531886
# 10                        Belo Horizonte -43.926453 -19.937524
# 11                          Campo Grande -54.615744 -20.458030
# 12                                Cuiabá -56.073252 -15.569989
# 13                          Belém (Pará) -48.487826  -1.459845
# 14                           João Pessoa -34.873385  -7.149382
# 15                                Recife -34.888942  -8.062762
# 16                              Teresina -42.805270  -5.086342
# 17                              Curitiba -49.271848 -25.432956
# 18               Rio de Janeiro (cidade) -43.227875 -22.876652
# 19           Natal (Rio Grande do Norte) -35.252255  -5.750899
# 20                           Porto Velho -63.831446  -8.768892
# 21                   Boa Vista (Roraima) -60.670533   2.816682
# 22                          Porto Alegre -51.228660 -30.030037
# 23                         Florianópolis -48.547637 -27.587796
# 24                               Aracaju -37.048213 -10.907216
# 25                    São Paulo (cidade) -46.570383 -23.567387
# 26                                Palmas -48.351044 -10.163253
#
#         no_accents       slug_name alternative_names    pop_21  id
# 0       Rio Branco      rio-branco               NaN    419452   0
# 1           Maceio          maceio               NaN   1031597   1
# 2           Manaus          manaus               NaN   2255903   2
# 3           Macapa          macapa               NaN    522357   3
# 4         Salvador        salvador               NaN   2900319   4
# 5        Fortaleza       fortaleza               NaN   2703391   5
# 6         Brasilia        brasilia               NaN   3094325   6
# 7          Vitoria         vitoria               NaN    369534   7
# 8          Goiania         goiania               NaN   1555626   8
# 9         Sao Luis        sao-luis               NaN   1115932   9
# 10  Belo Horizonte  belo-horizonte               NaN   2530701  10
# 11    Campo Grande    campo-grande               NaN    916001  11
# 12          Cuiaba          cuiaba               NaN    623614  12
# 13           Belem           belem               NaN   1506420  13
# 14     Joao Pessoa     joao-pessoa               NaN    825796  14
# 15          Recife          recife               NaN   1661017  15
# 16        Teresina        teresina               NaN    871126  16
# 17        Curitiba        curitiba               NaN   1963726  17
# 18  Rio de Janeiro  rio-de-janeiro               NaN   6775561  18
# 19           Natal           natal               NaN    896708  19
# 20     Porto Velho     porto-velho               NaN    548952  20
# 21       Boa Vista       boa-vista               NaN    436591  21
# 22    Porto Alegre    porto-alegre               NaN   1492530  22
# 23   Florianopolis   florianopolis               NaN    516524  23
# 24         Aracaju         aracaju               NaN    672614  24
# 25       Sao Paulo       sao-paulo               NaN  12396372  25
# 26          Palmas          palmas               NaN    313349  26

# %%
# converter dataframe para json
capitais_json = todas_capitais_ordem_alfabetica.to_json(orient='records')
capitais_json
# Out:
# '[{"municipio":1200401,"uf":12,"uf_code":"AC","name":"Rio Branco","mesoregion":1202,"microregion":12004,"rgint":1201,"rgi":120001,"osm_relation_id":326253,"wikidata_id":"Q171612","is_capital":true,"wikipedia_pt":"Rio Branco","lon":-67.8105287004,"lat":-9.9782987527,"no_accents":"Rio Branco","slug_name":"rio-branco","alternative_names":null,"pop_21":419452,"id":0},{"municipio":2704302,"uf":27,"uf_code":"AL","name":"Macei\\u00f3","mesoregion":2703,"microregion":27011,"rgint":2701,"rgi":270001,"osm_relation_id":303815,"wikidata_id":"Q168888","is_capital":true,"wikipedia_pt":"Macei\\u00f3","lon":-35.7016299135,"lat":-9.6608221516,"no_accents":"Maceio","slug_name":"maceio","alternative_names":null,"pop_21":1031597,"id":1},{"municipio":1302603,"uf":13,"uf_code":"AM","name":"Manaus","mesoregion":1303,"microregion":13007,"rgint":1301,"rgi":130001,"osm_relation_id":332493,"wikidata_id":"Q40236","is_capital":true,"wikipedia_pt":"Manaus","lon":-60.0233351811,"lat":-3.1346914912,"no_accents":"Manaus","slug_name":"manaus","alternative_names":null,"pop_21":2255903,"id":2},{"municipio":1600303,"uf":16,"uf_code":"AP","name":"Macap\\u00e1","mesoregion":1602,"microregion":16003,"rgint":1601,"rgi":160001,"osm_relation_id":331473,"wikidata_id":"Q180215","is_capital":true,"wikipedia_pt":"Macap\\u00e1","lon":-51.057405457,"lat":0.03895101,"no_accents":"Macapa","slug_name":"macapa","alternative_names":null,"pop_21":522357,"id":3},{"municipio":2927408,"uf":29,"uf_code":"BA","name":"Salvador","mesoregion":2905,"microregion":29021,"rgint":2901,"rgi":290001,"osm_relation_id":362362,"wikidata_id":"Q36947","is_capital":true,"wikipedia_pt":"Salvador (Bahia)","lon":-38.488061484,"lat":-13.0147719115,"no_accents":"Salvador","slug_name":"salvador","alternative_names":null,"pop_21":2900319,"id":4},{"municipio":2304400,"uf":23,"uf_code":"CE","name":"Fortaleza","mesoregion":2303,"microregion":23016,"rgint":2301,"rgi":230001,"osm_relation_id":302588,"wikidata_id":"Q43463","is_capital":true,"wikipedia_pt":"Fortaleza","lon":-38.589927555,"lat":-3.723805035,"no_accents":"Fortaleza","slug_name":"fortaleza","alternative_names":null,"pop_21":2703391,"id":5},{"municipio":5300108,"uf":53,"uf_code":"DF","name":"Bras\\u00edlia","mesoregion":5301,"microregion":53001,"rgint":5301,"rgi":530001,"osm_relation_id":2758138,"wikidata_id":"Q2844","is_capital":true,"wikipedia_pt":"Plano Piloto (regi\\u00e3o administrativa)","lon":-47.887905478,"lat":-15.7940873619,"no_accents":"Brasilia","slug_name":"brasilia","alternative_names":null,"pop_21":3094325,"id":6},{"municipio":3205309,"uf":32,"uf_code":"ES","name":"Vit\\u00f3ria","mesoregion":3203,"microregion":32009,"rgint":3201,"rgi":320001,"osm_relation_id":1825817,"wikidata_id":"Q168376","is_capital":true,"wikipedia_pt":"Vit\\u00f3ria (Esp\\u00edrito Santo)","lon":-40.3222087267,"lat":-20.3201537929,"no_accents":"Vitoria","slug_name":"vitoria","alternative_names":null,"pop_21":369534,"id":7},{"municipio":5208707,"uf":52,"uf_code":"GO","name":"Goi\\u00e2nia","mesoregion":5203,"microregion":52010,"rgint":5201,"rgi":520001,"osm_relation_id":334547,"wikidata_id":"Q83189","is_capital":true,"wikipedia_pt":"Goi\\u00e2nia","lon":-49.2558142758,"lat":-16.6733097738,"no_accents":"Goiania","slug_name":"goiania","alternative_names":null,"pop_21":1555626,"id":8},{"municipio":2111300,"uf":21,"uf_code":"MA","name":"S\\u00e3o Lu\\u00eds","mesoregion":2101,"microregion":21002,"rgint":2101,"rgi":210001,"osm_relation_id":332923,"wikidata_id":"Q28441","is_capital":true,"wikipedia_pt":"S\\u00e3o Lu\\u00eds (Maranh\\u00e3o)","lon":-44.2979185642,"lat":-2.5318859851,"no_accents":"Sao Luis","slug_name":"sao-luis","alternative_names":null,"pop_21":1115932,"id":9},{"municipio":3106200,"uf":31,"uf_code":"MG","name":"Belo Horizonte","mesoregion":3107,"microregion":31030,"rgint":3101,"rgi":310001,"osm_relation_id":368782,"wikidata_id":"Q42800","is_capital":true,"wikipedia_pt":"Belo Horizonte","lon":-43.9264531735,"lat":-19.9375242938,"no_accents":"Belo Horizonte ...

# %%
string_busca = 'blumenau'
resultado_busca = tabela[tabela['slug_name'].str.contains(string_busca, na=False)]
# Out:
#       municipio  uf uf_code      name  mesoregion  microregion  rgint     rgi  \
# 4347    4202404  42      SC  Blumenau        4204        42012   4207  420019
#
#       osm_relation_id wikidata_id is_capital wikipedia_pt        lon  \
# 4347           296522     Q155557        NaN     Blumenau -49.057631
#
#             lat no_accents slug_name alternative_names  pop_21    id
# 4347 -26.916108   Blumenau  blumenau               NaN  366418  4347

# %%
sorted(tabela['uf_code'].unique())
# Out:
# ['AC',
#  'AL',
#  'AM',
#  'AP',
#  'BA',
#  'CE',
#  'DF',
#  'ES',
#  'GO',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'RJ',
#  'RN',
#  'RO',
#  'RR',
#  'RS',
#  'SC',
#  'SE',
#  'SP',
#  'TO']

# %%
string_busca = 'SC'
#resultado_busca = tabela[tabela['uf_code'].str.contains(string_busca, na=False)]
resultado_busca = tabela.query(f'uf_code == "{string_busca}"')
resultado_busca = resultado_busca.to_json(orient='records')
resultado_busca
# Out:
# '[{"municipio":4200051,"uf":42,"uf_code":"SC","name":"Abdon Batista","mesoregion":4203,"microregion":42009,"rgint":4204,"rgi":420008,"osm_relation_id":296665,"wikidata_id":"Q1637414","is_capital":null,"wikipedia_pt":"Abdon Batista (Santa Catarina)","lon":-51.025272211,"lat":-27.6089871233,"no_accents":"Abdon Batista","slug_name":"abdon-batista","alternative_names":null,"pop_21":2534,"id":4311},{"municipio":4200101,"uf":42,"uf_code":"SC","name":"Abelardo Luz","mesoregion":4201,"microregion":42003,"rgint":4204,"rgi":420011,"osm_relation_id":296601,"wikidata_id":"Q1637506","is_capital":null,"wikipedia_pt":"Abelardo Luz","lon":-52.3364823833,"lat":-26.5630310224,"no_accents":"Abelardo Luz","slug_name":"abelardo-luz","alternative_names":null,"pop_21":18015,"id":4312},{"municipio":4200200,"uf":42,"uf_code":"SC","name":"Agrol\\u00e2ndia","mesoregion":4204,"microregion":42014,"rgint":4207,"rgi":420022,"osm_relation_id":296768,"wikidata_id":"Q397387","is_capital":null,"wikipedia_pt":"Agrol\\u00e2ndia","lon":-49.8256533877,"lat":-27.400516588,"no_accents":"Agrolandia","slug_name":"agrolandia","alternative_names":null,"pop_21":11160,"id":4313},{"municipio":4200309,"uf":42,"uf_code":"SC","name":"Agron\\u00f4mica","mesoregion":4204,"microregion":42011,"rgint":4207,"rgi":420022,"osm_relation_id":296564,"wikidata_id":"Q1754594","is_capital":null,"wikipedia_pt":"Agron\\u00f4mica","lon":-49.7183688908,"lat":-27.2697161071,"no_accents":"Agronomica","slug_name":"agronomica","alternative_names":null,"pop_21":5570,"id":4314},{"municipio":4200408,"uf":42,"uf_code":"SC","name":"\\u00c1gua Doce","mesoregion":4201,"microregion":42004,"rgint":4204,"rgi":420008,"osm_relation_id":296621,"wikidata_id":"Q1750762","is_capital":null,"wikipedia_pt":"\\u00c1gua Doce","lon":-51.5590965553,"lat":-27.0040916589,"no_accents":"Agua Doce","slug_name":"agua-doce","alternative_names":null,"pop_21":7160,"id":4315},{"municipio":4200507,"uf":42,"uf_code":"SC","name":"\\u00c1guas de Chapec\\u00f3","mesoregion":4201,"microregion":42002,"rgint":4204,"rgi":420007,"osm_relation_id":296580,"wikidata_id":"Q1750761","is_capital":null,"wikipedia_pt":"\\u00c1guas de Chapec\\u00f3","lon":-52.9872510057,"lat":-27.0762129125,"no_accents":"Aguas de Chapeco","slug_name":"aguas-de-chapeco","alternative_names":null,"pop_21":6544,"id":4316},{"municipio":4200556,"uf":42,"uf_code":"SC","name":"\\u00c1guas Frias","mesoregion":4201,"microregion":42002,"rgint":4204,"rgi":420007,"osm_relation_id":296574,"wikidata_id":"Q1796824","is_capital":null,"wikipedia_pt":"\\u00c1guas Frias (Santa Catarina)","lon":-52.8594194494,"lat":-26.880227543,"no_accents":"Aguas Frias","slug_name":"aguas-frias","alternative_names":null,"pop_21":2341,"id":4317},{"municipio":4200606,"uf":42,"uf_code":"SC","name":"\\u00c1guas Mornas","mesoregion":4205,"microregion":42017,"rgint":4201,"rgi":420001,"osm_relation_id":296576,"wikidata_id":"Q249844","is_capital":null,"wikipedia_pt":"\\u00c1guas Mornas","lon":-48.8405384028,"lat":-27.7065971917,"no_accents":"Aguas Mornas","slug_name":"aguas-mornas","alternative_names":null,"pop_21":6646,"id":4318},{"municipio":4200705,"uf":42,"uf_code":"SC","name":"Alfredo Wagner","mesoregion":4205,"microregion":42017,"rgint":4201,"rgi":420001,"osm_relation_id":296694,"wikidata_id":"Q1754557","is_capital":null,"wikipedia_pt":"Alfredo Wagner","lon":-49.3438123012,"lat":-27.705396332,"no_accents":"Alfredo Wagner","slug_name":"alfredo-wagner","alternative_names":null,"pop_21":10136,"id":4319},{"municipio":4200754,"uf":42,"uf_code":"SC","name":"Alto Bela Vista","mesoregion":4201,"microregion":42005,"rgint":4204,"rgi":420010,"osm_relation_id":296615,"wikidata_id":"Q1758023","is_capital":null,"wikipedia_pt":"Alto Bela Vista","lon":-51.9110368541,"lat":-27.4311378753,"no_accents":"Alto Bela Vista","slug_name":"alto-bela-vista","alternative_names":null,"pop_21":1915,"id":4320},{"municipio":4200804,"uf":42,"uf_code":"SC","name":"Anchieta","mesoregion":4201,"microregion":42001,"rgint":4204,"rgi":420009 ...
